# %% [markdown]
# # Merge Sort

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from datetime import datetime as dt
import random
import time

# %%
def arr_generate(n) -> list:
    return [random.randint(0, 2**15-1) for i in range(n)]

# %%
def mergesort(arr):
    n = len(arr)
    if n>1:
        A = arr[:n//2]
        B = [i for i in arr if i not in A]
        mergesort(A)
        mergesort(B)
        Merge(A,B,arr)
        
def Merge(A, B, arr):
    i=j=k=0
    while(i<len(A) and j<len(B)):
        if A[i]<B[j]:
            arr[k] = A[i]
            i+=1
        else:
            arr[k] = B[j]
            j+=1
        k+=1
        
    if i==len(A):
        arr[k:] = B[j:]
    else:
        arr[k:] = A[i:]

# %%
# %%timeit -n 50


arr = arr_generate(100)
mergesort(arr)
# Out:
# 1.17 ms ± 388 µs per loop (mean ± std. dev. of 7 runs, 50 loops each)

# %%
start = time.time()
arr = arr_generate(100)
mergesort(arr)
print(f"Sorted Array : {arr}")
time_taken = time.time() - start
print(f"\nTime Taken : {time_taken*1000} ms")
# Out:
# Sorted Array : [87, 136, 1054, 1806, 1811, 1940, 1974, 2015, 2058, 2145, 2172, 2504, 2735, 2792, 3053, 3299, 3427, 3459, 3487, 3578, 3601, 4153, 4707, 5686, 6178, 6223, 6469, 6529, 6942, 7233, 7336, 7803, 7805, 7858, 8492, 8963, 9355, 10074, 10675, 10707, 10959, 11300, 11389, 12145, 12223, 13467, 13699, 14082, 14147, 14629, 14840, 14995, 15226, 15493, 15620, 15661, 16014, 17290, 17879, 18056, 18587, 19672, 19880, 19907, 20103, 20261, 21330, 21381, 21823, 22028, 22128, 22168, 22227, 22450, 22570, 23382, 23417, 23564, 23687, 23997, 24088, 24381, 24396, 25654, 25965, 26053, 26304, 26987, 27299, 27655, 27895, 28927, 30034, 30375, 30382, 30492, 30549, 31605, 32213, 32245]
#
# Time Taken : 1.0340213775634766 ms
